# %% [markdown]
# ## Updating Data Exercise
#
# **This exercise uses the `netflix_titles.csv` dataset**

# %%
import pandas as pd
import os

# %%
# read in the netflix_titles.csv dataset.  Make sure to tell pandas to use the correct separator character!

netflix = pd.read_csv('../data/netflix_titles.csv', delimiter='|')
netflix.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# set the index to be the "show_id" (inplace)
netflix.set_index('show_id', inplace=True)
netflix.head()
# Out:
#          Unnamed: 0     type                  title         director  \
# show_id
# s1                0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2                1  TV Show          Blood & Water              NaN
# s3                2  TV Show              Ganglands  Julien Leclercq
# s4                3  TV Show  Jailbirds New Orleans              NaN
# s5                4  TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %%
# Find the row with the id of s2202 and set its director to "Greg Whiteley"
netflix.loc['s2202']
# Out:
# Unnamed: 0                                                   2201
# type                                                      TV Show
# title                                               Last Chance U
# director                                                      NaN
# cast            John Franklin III, DJ Law, Buddy Stephens, Bri...
# country                                             United States
# date_added                                          July 28, 2020
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                5 Seasons
# listed_in                                              Docuseries
# description     In a docuseries set at one of NCAA football's ...
# Name: s2202, dtype: object

# %%
# set its director to "Greg Whiteley"

netflix.loc['s2202', 'director'] = "Greg Whiteley"

netflix.loc['s2202', 'director']
# Out:
# 'Greg Whiteley'

# %%
#Update the "duration" of the shows with index s2881 and s3601 to be "GONE TOO SOON"

netflix.loc[['s2881', 's3601'], 'duration'] = 'GONE TOO SOON'

netflix.loc[['s2881', 's3601'], ['title','duration']]
# Out:
#                            title       duration
# show_id
# s2881    I Am Not Okay With This  GONE TOO SOON
# s3601                       GLOW  GONE TOO SOON

# %%
#rename the release_year column to "release_yr" in place

mapper = {'release_year':'release_yr'}
netflix.rename(columns=mapper, inplace=True)
netflix.columns
# Out:
# Index(['Unnamed: 0', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_yr', 'rating', 'duration', 'listed_in',
#        'description'],
#       dtype='object')

# %%
# Find the show called "Evil"
# Change its index label to s6666 inplace

evil = netflix['title'] == 'Evil'
netflix[evil]
mapper = {'s1907':'s6666'}

netflix[evil].rename(mapper,axis=0)
# Out:
#          Unnamed: 0     type title director  \
# show_id
# s6666          1906  TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s6666    Katja Herbers, Mike Colter, Aasif Mandvi, Mich...  United States
#
#               date_added  release_yr rating  duration  listed_in  \
# show_id
# s6666    October 1, 2020        2019  TV-14  1 Season  TV Dramas
#
#                                                description
# show_id
# s6666    A forensic psychologist partners with a Cathol...

# %%
# In the rating column, please replace all instances of "UR" and "NR" with "No Rating".  Don't do it inplace!

mask = (netflix['rating'] == 'UR') | (netflix['rating'] == 'NR')
netflix.loc[mask, ['rating']] = 'No Rating'
netflix[netflix['rating']== 'No Rating'].head()
# Out:
#          Unnamed: 0   type                       title  \
# show_id
# s5972          5971  Movie                    (T)ERROR
# s5988          5987  Movie                  13 Cameras
# s6016          6015  Movie                 4th Man Out
# s6055          6054  Movie  A Russell Peters Christmas
# s6088          6087  Movie            Act of Vengeance
#
#                                        director  \
# show_id
# s5972    Lyric R. Cabral, David Felix Sutcliffe
# s5988                            Victor Zarcoff
# s6016                            Andrew Nackman
# s6055                        Henry Sarwer-Foner
# s6088                         Mahsun Kırmızıgül
#
#                                                       cast  \
# show_id
# s5972                                                  NaN
# s5988    PJ McCabe, Brianne Moncrief, Sarah Baldwin, Ji...
# s6016    Evan Todd, Parker Young, Chord Overstreet, Jon...
# s6055    Russell Peters, Pamela Anderson, Michael Bublé...
# s6088    Haluk Bilginer, Mahsun Kırmızıgül, Mustafa San...
#
#                        country          date_added  release_yr     rating  \
# show_id
# s5972            United States       June 30, 2016        2015  No Rating
# s5988            United States     August 13, 2016        2015  No Rating
# s6016            United States         May 5, 2016        2015  No Rating
# s6055                   Canada    November 1, 2013        2011  No Rating
# s6088    Turkey, United States  September 29, 2018        2010  No Rating
#
#         duration                                     listed_in  \
# show_id
# s5972     84 min                                 Documentaries
# s5988     90 min  Horror Movies, Independent Movies, Thrillers
# s6016     86 min                        Comedies, LGBTQ Movies
# s6055     44 min                               Stand-Up Comedy
# s6088    112 min      Action & Adventure, International Movies
#
#                                                description
# show_id
# s5972    This real-life look at FBI counterterrorism op...
# s5988    Young parents-to-be Claire and Ryan move into ...
# s6016    A young mechanic comes out to his extremely st...
# s6055    Inspired by the variety shows of the 1970s, "A...
# s6088    Two Turkish agents are sent to New York City o...

# %%
netflix[netflix['rating'] == 'No Rating']['rating'].value_counts()
# Out:
# No Rating    83
# Name: rating, dtype: int64

# %%
# Add a new column "is_fav" and set it to False for all rows
# Update the "is_fav" column to True for the titles in my list of favs (provided below)
favs = ["Young Royals", "Dark", "Big Mouth", "BoJack Horseman", "The Queen's Gambit", "American Vandal", "Russian Doll", "Godless"]

netflix['is_fav'] = False
netflix.head()
# Out:
#          Unnamed: 0     type                  title         director  \
# show_id
# s1                0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2                1  TV Show          Blood & Water              NaN
# s3                2  TV Show              Ganglands  Julien Leclercq
# s4                3  TV Show  Jailbirds New Orleans              NaN
# s5                4  TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_yr rating   duration  \
# show_id
# s1       September 25, 2021        2020  PG-13     90 min
# s2       September 24, 2021        2021  TV-MA  2 Seasons
# s3       September 24, 2021        2021  TV-MA   1 Season
# s4       September 24, 2021        2021  TV-MA   1 Season
# s5       September 24, 2021        2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description  is_fav
# show_id
# s1       As her father nears the end of his life, filmm...   False
# s2       After crossing paths at a party, a Cape Town t...   False
# s3       To protect his family from a powerful drug lor...   False
# s4       Feuds, flirtations and toilet talk go down amo...   False
# s5       In a city of coaching centers known to train I...   False

# %%
# Update the "is_fav" column to True for the titles in my list of favs (provided below)
# -- Using a step-by-step approach:

mask = netflix['title'].isin(favs)
mask
netflix.loc[mask, 'is_fav'] = True
netflix['is_fav'].value_counts()
# Out:
# False    8799
# True        8
# Name: is_fav, dtype: int64

# %%
# Perfoming the same task in one line

netflix.loc[netflix['title'].isin(favs), 'is_fav'] = True

# %%
netflix[netflix['is_fav']]
# Out:
#          Unnamed: 0     type               title director  \
# show_id
# s618            617  TV Show        Young Royals      NaN
# s1591          1590  TV Show           Big Mouth      NaN
# s1805          1804  TV Show  The Queen's Gambit      NaN
# s2328          2327  TV Show                Dark      NaN
# s3370          3369  TV Show     BoJack Horseman      NaN
# s4143          4142  TV Show        Russian Doll      NaN
# s4637          4636  TV Show     American Vandal      NaN
# s5160          5159  TV Show             Godless      NaN
#
#                                                       cast  \
# show_id
# s618     Edvin Ryding, Omar Rudberg, Malte Gårdinger, F...
# s1591    Nick Kroll, John Mulaney, Jessi Klein, Jason M...
# s1805    Anya Taylor-Joy, Bill Camp, Marielle Heller, T...
# s2328    Louis Hofmann, Oliver Masucci, Jördis Triebel,...
# s3370    Will Arnett, Aaron Paul, Amy Sedaris, Alison B...
# s4143    Natasha Lyonne, Charlie Barnett, Yul Vazquez, ...
# s4637    Tyler Alvarez, Griffin Gluck, Jimmy Tatro, Cam...
# s5160    Jeff Daniels, Michelle Dockery, Jack O'Connell...
#
#                         country          date_added  release_yr rating  \
# show_id
# s618                     Sweden        July 1, 2021        2021  TV-MA
# s1591             United States    December 4, 2020        2020  TV-MA
# s1805             United States    October 23, 2020        2020  TV-MA
# s2328    Germany, United States       June 27, 2020        2020  TV-MA
# s3370             United States    October 25, 2019        2020  TV-MA
# s4143             United States    February 1, 2019        2019  TV-MA
# s4637             United States  September 14, 2018        2018  TV-MA
# s5160             United States   November 22, 2017        2017  TV-MA
#
#           duration                                          listed_in  \
# show_id
# s618      1 Season  International TV Shows, Romantic TV Shows, TV ...
# s1591    4 Seasons                                        TV Comedies
# s1805     1 Season                                          TV Dramas
# s2328    3 Seasons  Crime TV Shows, International TV Shows, TV Dramas
# s3370    6 Seasons                                        TV Comedies
# s4143     1 Season                             TV Comedies, TV Dramas
# s4637    2 Seasons         Crime TV Shows, TV Comedies, Teen TV Shows
# s5160     1 Season                                          TV Dramas
#
#                                                description  is_fav
# show_id
# s618     Prince Wilhelm adjusts to life at his prestigi...    True
# s1591    Teenage friends find their lives upended by th...    True
# s1805    In a 1950s orphanage, a young girl reveals an ...    True
# s2328    A missing child sets four families on a franti...    True
# s3370    Meet the most beloved sitcom horse of the '90s...    True
# s4143    Nadia keeps dying and reliving her 36th birthd...    True
# s4637    A high school is rocked by an act of vandalism...    True
# s5160    A ruthless outlaw terrorizes the West in searc...    True
